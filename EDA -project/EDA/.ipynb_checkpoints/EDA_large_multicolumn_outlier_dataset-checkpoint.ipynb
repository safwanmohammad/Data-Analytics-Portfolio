# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
df = pd.read_csv(r"C:\Users\babus\Data_Spark\Data_analysis_practice\Data Collection\large_multicolumn_outlier_dataset.csv")

# %%
df
# Out:
#         Customer_ID  Age  Annual_Income  Monthly_Spend  Savings  Credit_Score  \
# 0                 1   45          75548           1100     6687           807
# 1                 2   38          53376           2073     5071           672
# 2                 3   47          38753           1739    18463           629
# 3                 4   58          75879           1658    13109           654
# 4                 5   37          53302           2183    13239           780
# ...             ...  ...            ...            ...      ...           ...
# 149995       149996   49          48515           1706    15885           588
# 149996       149997   42          44688            966     8726           661
# 149997       149998   37          44805           1449    13804           655
# 149998       149999   41          38918           1400    14290           600
# 149999       150000   49          49632            931    14698           732
#
#         Loan_Amount  Transactions_Per_Month  Avg_Transaction_Value  \
# 0              2603                      21                     70
# 1             19182                      30                    108
# 2             40953                      30                     66
# 3             21312                      31                     77
# 4             45783                      33                     39
# ...             ...                     ...                    ...
# 149995        22499                      19                      8
# 149996        39990                      31                     70
# 149997        21050                      27                     17
# 149998        35213                      45                     59
# 149999        28275                      31                      5
#
#         Account_Tenure_Years  Online_Sessions_Per_Month  Returned_Transactions
# 0                          2                         19                      0
# 1                         16                         21                      1
# 2                          9                         21                      1
# 3                          8                         21                      3
# 4                         13                         22                      2
# ...                      ...                        ...                    ...
# 149995                     5                         14                      2
# 149996                     8                         21                      0
# 149997                     3                         20                      1
# 149998                     5                         19                      3
# 149999                    11                         23                      3
#
# [150000 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Customer_ID                150000 non-null  int64
#  1   Age                        150000 non-null  int64
#  2   Annual_Income              150000 non-null  int64
#  3   Monthly_Spend              150000 non-null  int64
#  4   Savings                    150000 non-null  int64
#  5   Credit_Score               150000 non-null  int64
#  6   Loan_Amount                150000 non-null  int64
#  7   Transactions_Per_Month     150000 non-null  int64
#  8   Avg_Transaction_Value      150000 non-null  int64
#  9   Account_Tenure_Years       150000 non-null  int64
#  10  Online_Sessions_Per_Month  150000 non-null  int64
#  11  Returned_Transactions      150000 non-null  int64
# dtypes: int64(12)
# memory usage: 13.7 MB

# %%
df.size
# Out:
# 1800000

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Annual_Income', 'Monthly_Spend', 'Savings',
#        'Credit_Score', 'Loan_Amount', 'Transactions_Per_Month',
#        'Avg_Transaction_Value', 'Account_Tenure_Years',
#        'Online_Sessions_Per_Month', 'Returned_Transactions'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Customer_ID                  150000
# Age                              71
# Annual_Income                 54863
# Monthly_Spend                  3482
# Savings                       32290
# Credit_Score                    592
# Loan_Amount                   46989
# Transactions_Per_Month           47
# Avg_Transaction_Value           158
# Account_Tenure_Years             25
# Online_Sessions_Per_Month        39
# Returned_Transactions            11
# dtype: int64

# %%
df['Credit_Score'].unique()
# Out:
# array([807, 672, 629, 654, 780, 734, 727, 634, 385, 728, 804, 671, 745,
#        704, 636, 721, 632, 744, 782, 645, 613, 748, 731, 561, 554, 760,
#        621, 752, 587, 717, 700, 696, 685, 597, 800, 751, 661, 674, 575,
#        445, 391, 310, 438, 458, 351, 400, 322, 454, 447, 446, 456, 899,
#        319, 395, 450, 461, 362, 344, 440, 402, 303, 422, 468, 355, 396,
#        360, 323, 416, 308, 411, 379, 408, 342, 371, 369, 366, 413, 414,
#        403, 347, 417, 317, 365, 300, 374, 409, 404, 401, 421, 420, 332,
#        389, 390, 392, 316, 321, 376, 388])

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Annual_Income', 'Monthly_Spend', 'Savings',
#        'Credit_Score', 'Loan_Amount', 'Transactions_Per_Month',
#        'Avg_Transaction_Value', 'Account_Tenure_Years',
#        'Online_Sessions_Per_Month', 'Returned_Transactions'],
#       dtype='object')

# %%
for col in df.columns:
    print(f"""{col}  :
        mean    | {df[col].mean()}
        median  | {df[col].median()}
        std     | {df[col].std()}               
        var     | {df[col].var()}
        skew    | {df[col].skew()}
        kurtosis| {df[col].kurtosis()}                
        """)
# Out:
# Customer_ID  :
#         mean    | 75000.5
#         median  | 75000.5
#         std     | 43301.414526548666
#         var     | 1875012500.0
#         skew    | 0.0
#         kurtosis| -1.2
#
# Age  :
#         mean    | 39.69900666666667
#         median  | 40.0
#         std     | 11.625207266233721
#         var     | 135.14544398289328
#         skew    | 0.17911391652350567
#         kurtosis| -0.319284640612576
#
# Annual_Income  :
#         mean    | 55759.3807
#         median  | 55010.0
#         std     | 21835.526566715685
#         var     | 476790220.4457464
#         skew    | 10.119501470899175
#         kurtosis| 209.67285174119394
#
# Monthly_Spend  :
#         mean    | 1822.1569933333333
#         median  | 1801.0
#         std     | 714.7224439092207
#         var     | 510828.17182756914
#         skew    | 9.23777372415838
#         kurtosis| 186.25500707926668
#
# Savings  :
#         mean    | 15270.963146666667
#         median  | 14999.0
#         std     | 9311.571621299774
#         var     | 86705366.0585953
#         skew    | 5.03244920217753
#         kurtosis| 94.69388443530471
#
# Credit_Score  :
#         mean    | 678.80478
#         median  | 680.0
#         std     | 71.64084546232318
#         var     | 5132.410738556472
#         skew    | -0.20283841422155843
#         kurtosis| 0.7197211060949447
#
# Loan_Amount  :
#         mean    | 20901.353593333333
#         median  | 20005.0
#         std     | 15577.477583947768
#         var     | 242657807.87839517
#         skew    | 3.4547172401009063
#         kurtosis| 56.00025310239874
#
# Transactions_Per_Month  :
#         mean    | 29.968593333333335
#         median  | 30.0
#         std     | 5.4617243147966406
#         var     | 29.830432490840835
#         skew    | 0.18169803436113663
#         kurtosis| 0.01947968453511617
#
# Avg_Transaction_Value  :
#         mean    | 59.506773333333335
#         median  | 59.0
#         std     | 24.701497023763714
#         var     | 610.1639552150077
#         skew    | 0.08873001079681682
#         kurtosis| -0.20255143490650918
#
# Account_Tenure_Years  :
#         mean    | 6.585426666666667
#         median  | 6.0
#         std     | 3.8326370658687385
#         var     | 14.689106878670934
#         skew    | 0.24250032544478745
#         kurtosis| -0.33323961210414454
#
# Online_Sessions_Per_Month  :
#         mean    | 20.00636666666667
#         median  | 20.0
#         std     | 4.479587024517328
#         var     | 20.06669991022401
#         skew    | 0.2262109480025721
#         kurtosis| 0.034532232023560816
#
# Returned_Transactions  :
#         mean    | 1.5003533333333334
#         median  | 1.0
#         std     | 1.22581533110776
#         var     | 1.5026232259788272
#         skew    | 0.8213769080673612
#         kurtosis| 0.6992581608297477

# %%
status = df.agg(['mean', 'median', 'std', 'var', 'skew', 'kurtosis'])
status
# Out:
#            Customer_ID         Age  Annual_Income  Monthly_Spend  \
# mean      7.500050e+04   39.699007   5.575938e+04    1822.156993
# median    7.500050e+04   40.000000   5.501000e+04    1801.000000
# std       4.330141e+04   11.625207   2.183553e+04     714.722444
# var       1.875012e+09  135.145444   4.767902e+08  510828.171828
# skew      0.000000e+00    0.179114   1.011950e+01       9.237774
# kurtosis -1.200000e+00   -0.319285   2.096729e+02     186.255007
#
#                Savings  Credit_Score   Loan_Amount  Transactions_Per_Month  \
# mean      1.527096e+04    678.804780  2.090135e+04               29.968593
# median    1.499900e+04    680.000000  2.000500e+04               30.000000
# std       9.311572e+03     71.640845  1.557748e+04                5.461724
# var       8.670537e+07   5132.410739  2.426578e+08               29.830432
# skew      5.032449e+00     -0.202838  3.454717e+00                0.181698
# kurtosis  9.469388e+01      0.719721  5.600025e+01                0.019480
#
#           Avg_Transaction_Value  Account_Tenure_Years  \
# mean                  59.506773              6.585427
# median                59.000000              6.000000
# std                   24.701497              3.832637
# var                  610.163955             14.689107
# skew                   0.088730              0.242500
# kurtosis              -0.202551             -0.333240
#
#           Online_Sessions_Per_Month  Returned_Transactions
# mean                      20.006367               1.500353
# median                    20.000000               1.000000
# std                        4.479587               1.225815
# var                       20.066700               1.502623
# skew                       0.226211               0.821377
# kurtosis                   0.034532               0.699258

# %% [markdown]
# # BOXPLOT

# %%
for col in df.columns:
    plt.figure(figsize=(12,4))
    plt.boxplot(df[col],patch_artist=True)
    plt.title(f"__{col}__")
    plt.grid()
    plt.show()

# %%
for col in df.columns:
    plt.figure(figsize=(10,4))
    sns.boxplot(df[col],color='r')
    plt.grid()
    plt.title(f"__{col}__")
    plt.show()

# %%
df.count()
# Out:
# Customer_ID                  150000
# Age                          150000
# Annual_Income                150000
# Monthly_Spend                150000
# Savings                      150000
# Credit_Score                 150000
# Loan_Amount                  150000
# Transactions_Per_Month       150000
# Avg_Transaction_Value        150000
# Account_Tenure_Years         150000
# Online_Sessions_Per_Month    150000
# Returned_Transactions        150000
# dtype: int64

# %%
len(df.columns)
# Out:
# 12

# %%
df.shape
# Out:
# (150000, 12)

# %% [markdown]
# # SUBPLOT

# %%
plt.figure(figsize=(15,15))   
for i,col in enumerate(df.columns,start=1):
    plt.subplot(3,4,i)
    plt.boxplot(df[col],patch_artist=True)
    plt.title(f"__{col}__")
    plt.grid()
plt.subplots_adjust(wspace=0.5,hspace=0.5)
plt.show()

# %%
df.plot(kind='box', subplots=True,color='r', layout=(7, 2), figsize=(15, 15),grid=True, title=list(df.columns),patch_artist=True)
plt.subplots_adjust(wspace=0.5,hspace=1)

# %%
# for col in df.columns:
#     plt.scatter(x=df['Customer_ID'],y=df[col])
#     plt.title(f"__{col}__")
#     plt.show()
