# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Los Angeles', 'Chicago']
}

# %%
data
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie'],
#  'Age': [25, 30, 35],
#  'City': ['New York', 'Los Angeles', 'Chicago']}

# %%
df = pd.DataFrame(data,index=['a','b','c'])

# %%
df
# Out:
#       Name  Age         City
# a    Alice   25     New York
# b      Bob   30  Los Angeles
# c  Charlie   35      Chicago

# %%
il = df.iloc[1]
il
# Out:
# Name            Bob
# Age              30
# City    Los Angeles
# Name: b, dtype: object

# %%
lo = df.loc[df['Age'] > 30]
lo
# Out:
#       Name  Age     City
# c  Charlie   35  Chicago

# %%
lo = df.loc[
    (df['Age'] >= 30) &
    (df['City'].str.strip().str.lower() == 'los angeles')
]
lo
# Out:
#   Name  Age         City
# b  Bob   30  Los Angeles
